# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt # Visuals
import seaborn as sns
import sklearn as skl
import pandas as pd
import sys
Cleveland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
#Hungarian_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
#Switzerland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.switzerland.data'
np.set_printoptions(threshold=sys.maxsize) #see a whole array when we output it
names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach','exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease']
heartDisease = pd.read_csv(urlopen(Cleveland_data_URL), names = names) #gets Cleveland data
#HungarianHeartDisease = pd.read_csv(urlopen(Hungarian_data_URL), names = names) #gets Hungary data
#SwitzerlandHeartDisease = pd.read_csv(urlopen(Switzerland_data_URL), names = names) #gets Switzerland data
#datatemp = [ClevelandHeartDisease, HungarianHeartDisease,SwitzerlandHeartDisease] #combines all arrays into a list
#heartDisease = pd.concat(datatemp)#combines list into one array
heartDisease.head()
del heartDisease['ca']
del heartDisease['slope']
del heartDisease['thal']
del heartDisease['oldpeak']
heartDisease = heartDisease.replace('?', np.nan)
heartDisease.dtypes
heartDisease.columns
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator
model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'), ('sex','trestbps'), ('sex', 'trestbps'),('exang','trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),('heartdisease','restecg'),('heartdisease','thalach'),('heartdisease','chol')])
# Learing CPDs using Maximum Likelihood Estimators
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
#for cpd in model.get_cpds():
# print("CPD of {variable}:".format(variable=cpd.variable))
# print(cpd)
print(model.get_cpds('age'))
print(model.get_cpds('chol'))
print(model.get_cpds('sex'))
model.get_independencies()
# Out:
# /home/user/.local/lib/python3.7/site-packages/pgmpy/estimators/base.py:54: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   states = sorted(list(self.data.ix[:, variable].dropna().unique()))
# /home/user/.local/lib/python3.7/site-packages/pgmpy/estimators/base.py:116: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   state_count_data = data.ix[:, variable].value_counts()
# /home/user/.local/lib/python3.7/site-packages/pgmpy/estimators/MLE.py:128: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   state_counts.ix[:, (state_counts == 0).all()] = 1
# +---------+------------+
# | age(28) | 0.00383142 |
# +---------+------------+
# | age(29) | 0.00383142 |
# +---------+------------+
# | age(30) | 0.00383142 |
# +---------+------------+
# | age(31) | 0.00766284 |
# +---------+------------+
# | age(32) | 0.0153257  |
# +---------+------------+
# | age(33) | 0.00766284 |
# +---------+------------+
# | age(34) | 0.0153257  |
# +---------+------------+
# | age(35) | 0.0191571  |
# +---------+------------+
# | age(36) | 0.0191571  |
# +---------+------------+
# | age(37) | 0.0306513  |
# +---------+------------+
# | age(38) | 0.0191571  |
# +---------+------------+
# | age(39) | 0.0344828  |
# +---------+------------+
# | age(40) | 0.0191571  |
# +---------+------------+
# | age(41) | 0.0383142  |
# +---------+------------+
# | age(42) | 0.0268199  |
# +---------+------------+
# | age(43) | 0.0421456  |
# +---------+------------+
# | age(44) | 0.0268199  |
# +---------+------------+
# | age(45) | 0.0229885  |
# +---------+------------+
# | age(46) | 0.045977   |
# +---------+------------+
# | age(47) | 0.0344828  |
# +---------+------------+
# | age(48) | 0.0613027  |
# +---------+------------+
# | age(49) | 0.0421456  |
# +---------+------------+
# | age(50) | 0.045977   |
# +---------+------------+
# | age(51) | 0.0344828  |
# +---------+------------+
# | age(52) | 0.0574713  |
# +---------+------------+
# | age(53) | 0.0383142  |
# +---------+------------+
# | age(54) | 0.0842912  |
# +---------+------------+
# | age(55) | 0.0536398  |
# +---------+------------+
# | age(56) | 0.0306513  |
# +---------+------------+
# | age(57) | 0.0191571  |
# +---------+------------+
# | age(58) | 0.0344828  |
# +---------+------------+
# | age(59) | 0.0229885  |
# +---------+------------+
# | age(60) | 0.00766284 |
# +---------+------------+
# | age(61) | 0.00766284 |
# +---------+------------+
# | age(62) | 0.00766284 |
# +---------+------------+
# | age(63) | 0.00383142 |
# +---------+------------+
# | age(65) | 0.0114943  |
# +---------+------------+
# | age(66) | 0          |
# +---------+------------+
# +--------------+----------------------+----------------------+
# | heartdisease | heartdisease(0)      | heartdisease(1)      |
# +--------------+----------------------+----------------------+
# | chol(100)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(117)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(129)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(132)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(147)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(156)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(160)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(161)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(163)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(164)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(166)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(167)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(168)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(171)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(172)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(173)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(175)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(179)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(180)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(182)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(184)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(186)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(187)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(188)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(190)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(193)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(194)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(195)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(196)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(198)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(200)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(201)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(202)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(204)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(205)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(206)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(207)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(208)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(209)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(210)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(211)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(212)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(213)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(214)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(215)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(216)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(217)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(218)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(219)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(220)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(221)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(222)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(223)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(224)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(225)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(226)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(227)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(228)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(229)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(230)    | 0.024539877300613498 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(231)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(233)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(234)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(237)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(238)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(240)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(241)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(242)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(243)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(245)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(246)    | 0.012269938650306749 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(247)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(248)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(249)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(250)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(251)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(253)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(254)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(255)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(256)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(257)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(259)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(260)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(263)    | 0.006134969325153374 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(264)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(265)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(266)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(267)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(268)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(269)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(270)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(271)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(272)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(273)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(274)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(275)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(276)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(277)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(279)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(280)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(281)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(282)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(283)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(284)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(285)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(287)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(288)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(289)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(290)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(291)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(292)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(294)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(295)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(297)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(298)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(303)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(305)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(306)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(307)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(308)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(309)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(312)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(315)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(318)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(320)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(326)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(328)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(329)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(331)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(336)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(338)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(339)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(340)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(341)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(342)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(344)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(347)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(355)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(358)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(365)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(388)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(392)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(393)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(394)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(404)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(412)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(466)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(468)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(491)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(518)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(529)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(603)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(85)     | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# +--------+----------+
# | sex(0) | 0.264368 |
# +--------+----------+
# | sex(1) | 0.735632 |
# +--------+----------+
# (age _|_ exang, sex)
# (age _|_ exang, sex | fbs)
# (age _|_ sex | exang)
# (age _|_ thalach, chol, restecg | heartdisease)
# (age _|_ exang | sex)
# (age _|_ sex | fbs, exang)
# (age _|_ thalach, chol, restecg, heartdisease | fbs, trestbps)
# (age _|_ chol, restecg, thalach | fbs, heartdisease)
# (age _|_ exang | fbs, sex)
# (age _|_ chol, restecg, thalach | exang, heartdisease)
# (age _|_ restecg, thalach | chol, heartdisease)
# (age _|_ chol, restecg, thalach | heartdisease, trestbps)
# (age _|_ chol, thalach | restecg, heartdisease)
# (age _|_ chol, restecg | thalach, heartdisease)
# (age _|_ thalach, chol, restecg | sex, heartdisease)
# (age _|_ thalach, chol, restecg, heartdisease | fbs, exang, trestbps)
# (age _|_ chol, restecg, thalach | fbs, exang, heartdisease)
# (age _|_ thalach, restecg, heartdisease | fbs, chol, trestbps)
# (age _|_ restecg, thalach | fbs, chol, heartdisease)
# (age _|_ chol, restecg, thalach | fbs, heartdisease, trestbps)
# (age _|_ thalach, chol, heartdisease | fbs, restecg, trestbps)
# (age _|_ chol, restecg, heartdisease | fbs, thalach, trestbps)
# (age _|_ thalach, chol, restecg, heartdisease | fbs, sex, trestbps)
# (age _|_ chol, thalach | fbs, restecg, heartdisease)
# (age _|_ chol, restecg | fbs, thalach, heartdisease)
# (age _|_ chol, restecg, thalach | fbs, sex, heartdisease)
# (age _|_ restecg, thalach | exang, chol, heartdisease)
# (age _|_ chol, restecg, thalach | exang, heartdisease, trestbps)
# (age _|_ chol, thalach | exang, restecg, heartdisease)
# (age _|_ chol, restecg | thalach, exang, heartdisease)
# (age _|_ chol, restecg, thalach | exang, sex, heartdisease)
# (age _|_ restecg, thalach | chol, heartdisease, trestbps)
# (age _|_ thalach | chol, restecg, heartdisease)
# (age _|_ restecg | thalach, chol, heartdisease)
# (age _|_ restecg, thalach | sex, chol, heartdisease)
# (age _|_ chol, thalach | restecg, heartdisease, trestbps)
# (age _|_ chol, restecg | thalach, heartdisease, trestbps)
# (age _|_ chol, restecg, thalach | sex, heartdisease, trestbps)
# (age _|_ chol | thalach, restecg, heartdisease)
# (age _|_ chol, thalach | sex, restecg, heartdisease)
# (age _|_ chol, restecg | thalach, sex, heartdisease)
# (age _|_ heartdisease, restecg, thalach | fbs, exang, chol, trestbps)
# (age _|_ restecg, thalach | fbs, exang, chol, heartdisease)
# (age _|_ chol, restecg, thalach | fbs, exang, heartdisease, trestbps)
# (age _|_ heartdisease, chol, thalach | fbs, exang, restecg, trestbps)
# (age _|_ heartdisease, chol, restecg | fbs, exang, thalach, trestbps)
# (age _|_ heartdisease, chol, restecg, thalach | fbs, exang, sex, trestbps)
# (age _|_ chol, thalach | fbs, exang, restecg, heartdisease)
# (age _|_ chol, restecg | fbs, exang, thalach, heartdisease)
# (age _|_ chol, restecg, thalach | fbs, exang, sex, heartdisease)
# (age _|_ restecg, thalach | fbs, chol, heartdisease, trestbps)
# (age _|_ heartdisease, thalach | fbs, chol, restecg, trestbps)
# (age _|_ heartdisease, restecg | fbs, chol, thalach, trestbps)
# (age _|_ heartdisease, restecg, thalach | fbs, sex, chol, trestbps)
# (age _|_ thalach | fbs, chol, restecg, heartdisease)
# (age _|_ restecg | fbs, chol, thalach, heartdisease)
# (age _|_ restecg, thalach | fbs, sex, chol, heartdisease)
# (age _|_ chol, thalach | fbs, restecg, heartdisease, trestbps)
# (age _|_ chol, restecg | fbs, thalach, heartdisease, trestbps)
# (age _|_ chol, restecg, thalach | fbs, sex, heartdisease, trestbps)
# (age _|_ chol, heartdisease | fbs, thalach, restecg, trestbps)
# (age _|_ heartdisease, chol, thalach | fbs, sex, restecg, trestbps)
# (age _|_ heartdisease, chol, restecg | fbs, sex, thalach, trestbps)
# (age _|_ chol | fbs, thalach, restecg, heartdisease)
# (age _|_ chol, thalach | fbs, sex, restecg, heartdisease)
# (age _|_ chol, restecg | fbs, sex, thalach, heartdisease)
# (age _|_ restecg, thalach | exang, chol, heartdisease, trestbps)
# (age _|_ thalach | exang, chol, restecg, heartdisease)
# (age _|_ restecg | thalach, exang, chol, heartdisease)
# (age _|_ restecg, thalach | exang, chol, sex, heartdisease)
# (age _|_ chol, thalach | exang, restecg, heartdisease, trestbps)
# (age _|_ chol, restecg | thalach, exang, heartdisease, trestbps)
# (age _|_ chol, restecg, thalach | exang, sex, heartdisease, trestbps)
# (age _|_ chol | thalach, exang, restecg, heartdisease)
# (age _|_ chol, thalach | exang, restecg, sex, heartdisease)
# (age _|_ chol, restecg | thalach, exang, sex, heartdisease)
# (age _|_ thalach | chol, restecg, heartdisease, trestbps)
# (age _|_ restecg | thalach, chol, heartdisease, trestbps)
# (age _|_ restecg, thalach | sex, chol, heartdisease, trestbps)
# (age _|_ thalach | sex, chol, restecg, heartdisease)
# (age _|_ restecg | thalach, sex, chol, heartdisease)
# (age _|_ chol | thalach, restecg, heartdisease, trestbps)
# (age _|_ chol, thalach | sex, restecg, heartdisease, trestbps)
# (age _|_ chol, restecg | thalach, sex, heartdisease, trestbps)
# (age _|_ chol | thalach, sex, restecg, heartdisease)
# (age _|_ restecg, thalach | fbs, exang, chol, trestbps, heartdisease)
# (age _|_ heartdisease, thalach | fbs, exang, chol, trestbps, restecg)
# (age _|_ heartdisease, restecg | fbs, exang, chol, trestbps, thalach)
# (age _|_ heartdisease, restecg, thalach | fbs, exang, chol, trestbps, sex)
# (age _|_ thalach | fbs, exang, chol, heartdisease, restecg)
# (age _|_ restecg | fbs, exang, chol, heartdisease, thalach)
# (age _|_ restecg, thalach | fbs, exang, chol, heartdisease, sex)
# (age _|_ chol, thalach | fbs, exang, trestbps, heartdisease, restecg)
# (age _|_ chol, restecg | fbs, exang, trestbps, heartdisease, thalach)
# (age _|_ chol, restecg, thalach | fbs, exang, trestbps, heartdisease, sex)
# (age _|_ chol, heartdisease | fbs, exang, trestbps, thalach, restecg)
# (age _|_ heartdisease, chol, thalach | fbs, exang, trestbps, restecg, sex)
# (age _|_ heartdisease, chol, restecg | fbs, exang, trestbps, thalach, sex)
# (age _|_ chol | fbs, exang, heartdisease, thalach, restecg)
# (age _|_ chol, thalach | fbs, exang, heartdisease, restecg, sex)
# (age _|_ chol, restecg | fbs, exang, heartdisease, thalach, sex)
# (age _|_ thalach | fbs, chol, trestbps, heartdisease, restecg)
# (age _|_ restecg | fbs, chol, trestbps, heartdisease, thalach)
# (age _|_ restecg, thalach | fbs, chol, trestbps, heartdisease, sex)
# (age _|_ heartdisease | fbs, chol, trestbps, thalach, restecg)
# (age _|_ heartdisease, thalach | fbs, chol, trestbps, restecg, sex)
# (age _|_ heartdisease, restecg | fbs, chol, trestbps, thalach, sex)
# (age _|_ thalach | fbs, chol, heartdisease, restecg, sex)
# (age _|_ restecg | fbs, chol, heartdisease, thalach, sex)
# (age _|_ chol | fbs, trestbps, heartdisease, thalach, restecg)
# (age _|_ chol, thalach | fbs, trestbps, heartdisease, restecg, sex)
# (age _|_ chol, restecg | fbs, trestbps, heartdisease, thalach, sex)
# (age _|_ chol, heartdisease | fbs, trestbps, thalach, restecg, sex)
# (age _|_ chol | fbs, heartdisease, thalach, restecg, sex)
# (age _|_ thalach | exang, chol, trestbps, heartdisease, restecg)
# (age _|_ restecg | exang, chol, trestbps, heartdisease, thalach)
# (age _|_ restecg, thalach | exang, chol, trestbps, heartdisease, sex)
# (age _|_ thalach | exang, chol, heartdisease, restecg, sex)
# (age _|_ restecg | exang, chol, heartdisease, thalach, sex)
# (age _|_ chol | exang, trestbps, heartdisease, thalach, restecg)
# (age _|_ chol, thalach | exang, trestbps, heartdisease, restecg, sex)
# (age _|_ chol, restecg | exang, trestbps, heartdisease, thalach, sex)
# (age _|_ chol | exang, heartdisease, thalach, restecg, sex)
# (age _|_ thalach | chol, trestbps, heartdisease, restecg, sex)
# (age _|_ restecg | chol, trestbps, heartdisease, thalach, sex)
# (age _|_ chol | trestbps, heartdisease, thalach, restecg, sex)
# (age _|_ thalach | fbs, exang, chol, trestbps, heartdisease, restecg)
# (age _|_ restecg | fbs, exang, chol, trestbps, heartdisease, thalach)
# (age _|_ restecg, thalach | fbs, exang, chol, trestbps, heartdisease, sex)
# (age _|_ heartdisease | fbs, exang, chol, trestbps, restecg, thalach)
# (age _|_ heartdisease, thalach | fbs, exang, chol, trestbps, restecg, sex)
# (age _|_ heartdisease, restecg | fbs, exang, chol, trestbps, thalach, sex)
# (age _|_ thalach | fbs, exang, chol, heartdisease, restecg, sex)
# (age _|_ restecg | fbs, exang, chol, heartdisease, thalach, sex)
# (age _|_ chol | fbs, exang, trestbps, heartdisease, restecg, thalach)
# (age _|_ chol, thalach | fbs, exang, trestbps, heartdisease, restecg, sex)
# (age _|_ chol, restecg | fbs, exang, trestbps, heartdisease, thalach, sex)
# (age _|_ chol, heartdisease | fbs, exang, trestbps, thalach, restecg, sex)
# (age _|_ chol | fbs, exang, heartdisease, thalach, restecg, sex)
# (age _|_ thalach | fbs, chol, trestbps, heartdisease, restecg, sex)
# (age _|_ restecg | fbs, chol, trestbps, heartdisease, thalach, sex)
# (age _|_ heartdisease | fbs, chol, trestbps, thalach, restecg, sex)
# (age _|_ chol | fbs, trestbps, heartdisease, thalach, restecg, sex)
# (age _|_ thalach | exang, chol, trestbps, heartdisease, restecg, sex)
# (age _|_ restecg | exang, chol, trestbps, heartdisease, thalach, sex)
# (age _|_ chol | exang, trestbps, heartdisease, thalach, restecg, sex)
# (age _|_ thalach | fbs, exang, chol, trestbps, heartdisease, restecg, sex)
# (age _|_ restecg | fbs, exang, chol, trestbps, heartdisease, thalach, sex)
# (age _|_ heartdisease | fbs, exang, chol, trestbps, restecg, thalach, sex)
# (age _|_ chol | fbs, exang, trestbps, heartdisease, restecg, thalach, sex)
# (trestbps _|_ thalach, chol, restecg | heartdisease)
# (trestbps _|_ fbs | age)
# (trestbps _|_ chol, restecg, thalach | fbs, heartdisease)
# (trestbps _|_ chol, restecg, thalach | exang, heartdisease)
# (trestbps _|_ fbs | age, exang)
# (trestbps _|_ restecg, thalach | chol, heartdisease)
# (trestbps _|_ chol, restecg, thalach | age, heartdisease)
# (trestbps _|_ chol, thalach | restecg, heartdisease)
# (trestbps _|_ chol, restecg | thalach, heartdisease)
# (trestbps _|_ thalach, chol, restecg | sex, heartdisease)
# (trestbps _|_ fbs | age, sex)
# (trestbps _|_ chol, restecg, thalach | fbs, exang, heartdisease)
# (trestbps _|_ restecg, thalach | fbs, chol, heartdisease)
# (trestbps _|_ chol, restecg, thalach | fbs, age, heartdisease)
# (trestbps _|_ chol, thalach | fbs, restecg, heartdisease)
# (trestbps _|_ chol, restecg | fbs, thalach, heartdisease)
# (trestbps _|_ chol, restecg, thalach | fbs, sex, heartdisease)
# (trestbps _|_ restecg, thalach | exang, chol, heartdisease)
# (trestbps _|_ chol, restecg, thalach | age, exang, heartdisease)
# (trestbps _|_ chol, thalach | exang, restecg, heartdisease)
# (trestbps _|_ chol, restecg | thalach, exang, heartdisease)
# (trestbps _|_ chol, restecg, thalach | exang, sex, heartdisease)
# (trestbps _|_ fbs | age, exang, sex)
# (trestbps _|_ restecg, thalach | age, chol, heartdisease)
# (trestbps _|_ thalach | chol, restecg, heartdisease)
# (trestbps _|_ restecg | thalach, chol, heartdisease)
# (trestbps _|_ restecg, thalach | sex, chol, heartdisease)
# (trestbps _|_ chol, thalach | age, restecg, heartdisease)
# (trestbps _|_ chol, restecg | age, thalach, heartdisease)
# (trestbps _|_ chol, restecg, thalach | age, sex, heartdisease)
# (trestbps _|_ chol | thalach, restecg, heartdisease)
# (trestbps _|_ chol, thalach | sex, restecg, heartdisease)
# (trestbps _|_ chol, restecg | thalach, sex, heartdisease)
# (trestbps _|_ restecg, thalach | fbs, exang, chol, heartdisease)
# (trestbps _|_ chol, restecg, thalach | fbs, exang, age, heartdisease)
# (trestbps _|_ chol, thalach | fbs, exang, restecg, heartdisease)
# (trestbps _|_ chol, restecg | fbs, exang, thalach, heartdisease)
# (trestbps _|_ chol, restecg, thalach | fbs, exang, sex, heartdisease)
# (trestbps _|_ restecg, thalach | fbs, age, chol, heartdisease)
# (trestbps _|_ thalach | fbs, chol, restecg, heartdisease)
# (trestbps _|_ restecg | fbs, chol, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | fbs, sex, chol, heartdisease)
# (trestbps _|_ chol, thalach | fbs, age, restecg, heartdisease)
# (trestbps _|_ chol, restecg | fbs, age, thalach, heartdisease)
# (trestbps _|_ chol, restecg, thalach | fbs, age, sex, heartdisease)
# (trestbps _|_ chol | fbs, thalach, restecg, heartdisease)
# (trestbps _|_ chol, thalach | fbs, sex, restecg, heartdisease)
# (trestbps _|_ chol, restecg | fbs, sex, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | age, exang, chol, heartdisease)
# (trestbps _|_ thalach | exang, chol, restecg, heartdisease)
# (trestbps _|_ restecg | thalach, exang, chol, heartdisease)
# (trestbps _|_ restecg, thalach | exang, chol, sex, heartdisease)
# (trestbps _|_ chol, thalach | age, exang, restecg, heartdisease)
# (trestbps _|_ chol, restecg | age, exang, thalach, heartdisease)
# (trestbps _|_ chol, restecg, thalach | age, exang, sex, heartdisease)
# (trestbps _|_ chol | thalach, exang, restecg, heartdisease)
# (trestbps _|_ chol, thalach | exang, restecg, sex, heartdisease)
# (trestbps _|_ chol, restecg | thalach, exang, sex, heartdisease)
# (trestbps _|_ thalach | age, chol, restecg, heartdisease)
# (trestbps _|_ restecg | age, chol, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | age, sex, chol, heartdisease)
# (trestbps _|_ thalach | sex, chol, restecg, heartdisease)
# (trestbps _|_ restecg | thalach, sex, chol, heartdisease)
# (trestbps _|_ chol | age, thalach, restecg, heartdisease)
# (trestbps _|_ chol, thalach | age, sex, restecg, heartdisease)
# (trestbps _|_ chol, restecg | age, sex, thalach, heartdisease)
# (trestbps _|_ chol | thalach, sex, restecg, heartdisease)
# (trestbps _|_ restecg, thalach | fbs, exang, chol, heartdisease, age)
# (trestbps _|_ thalach | fbs, exang, chol, heartdisease, restecg)
# (trestbps _|_ restecg | fbs, exang, chol, heartdisease, thalach)
# (trestbps _|_ restecg, thalach | fbs, exang, chol, heartdisease, sex)
# (trestbps _|_ chol, thalach | fbs, exang, heartdisease, age, restecg)
# (trestbps _|_ chol, restecg | fbs, exang, heartdisease, age, thalach)
# (trestbps _|_ chol, restecg, thalach | fbs, exang, heartdisease, age, sex)
# (trestbps _|_ chol | fbs, exang, heartdisease, thalach, restecg)
# (trestbps _|_ chol, thalach | fbs, exang, heartdisease, restecg, sex)
# (trestbps _|_ chol, restecg | fbs, exang, heartdisease, thalach, sex)
# (trestbps _|_ thalach | fbs, chol, heartdisease, age, restecg)
# (trestbps _|_ restecg | fbs, chol, heartdisease, age, thalach)
# (trestbps _|_ restecg, thalach | fbs, chol, heartdisease, age, sex)
# (trestbps _|_ thalach | fbs, chol, heartdisease, restecg, sex)
# (trestbps _|_ restecg | fbs, chol, heartdisease, thalach, sex)
# (trestbps _|_ chol | fbs, heartdisease, age, thalach, restecg)
# (trestbps _|_ chol, thalach | fbs, heartdisease, age, restecg, sex)
# (trestbps _|_ chol, restecg | fbs, heartdisease, age, thalach, sex)
# (trestbps _|_ chol | fbs, heartdisease, thalach, restecg, sex)
# (trestbps _|_ thalach | exang, chol, heartdisease, age, restecg)
# (trestbps _|_ restecg | exang, chol, heartdisease, age, thalach)
# (trestbps _|_ restecg, thalach | exang, chol, heartdisease, age, sex)
# (trestbps _|_ thalach | exang, chol, heartdisease, restecg, sex)
# (trestbps _|_ restecg | exang, chol, heartdisease, thalach, sex)
# (trestbps _|_ chol | exang, heartdisease, age, thalach, restecg)
# (trestbps _|_ chol, thalach | exang, heartdisease, age, restecg, sex)
# (trestbps _|_ chol, restecg | exang, heartdisease, age, thalach, sex)
# (trestbps _|_ chol | exang, heartdisease, thalach, restecg, sex)
# (trestbps _|_ thalach | chol, heartdisease, age, restecg, sex)
# (trestbps _|_ restecg | chol, heartdisease, age, thalach, sex)
# (trestbps _|_ chol | heartdisease, age, thalach, restecg, sex)
# (trestbps _|_ thalach | fbs, exang, chol, heartdisease, age, restecg)
# (trestbps _|_ restecg | fbs, exang, chol, heartdisease, age, thalach)
# (trestbps _|_ restecg, thalach | fbs, exang, chol, heartdisease, age, sex)
# (trestbps _|_ thalach | fbs, exang, chol, heartdisease, restecg, sex)
# (trestbps _|_ restecg | fbs, exang, chol, heartdisease, thalach, sex)
# (trestbps _|_ chol | fbs, exang, heartdisease, age, restecg, thalach)
# (trestbps _|_ chol, thalach | fbs, exang, heartdisease, age, restecg, sex)
# (trestbps _|_ chol, restecg | fbs, exang, heartdisease, age, thalach, sex)
# (trestbps _|_ chol | fbs, exang, heartdisease, thalach, restecg, sex)
# (trestbps _|_ thalach | fbs, chol, heartdisease, age, restecg, sex)
# (trestbps _|_ restecg | fbs, chol, heartdisease, age, thalach, sex)
# (trestbps _|_ chol | fbs, heartdisease, age, thalach, restecg, sex)
# (trestbps _|_ thalach | exang, chol, heartdisease, age, restecg, sex)
# (trestbps _|_ restecg | exang, chol, heartdisease, age, thalach, sex)
# (trestbps _|_ chol | exang, heartdisease, age, thalach, restecg, sex)
# (trestbps _|_ thalach | fbs, exang, chol, heartdisease, age, restecg, sex)
# (trestbps _|_ restecg | fbs, exang, chol, heartdisease, age, thalach, sex)
# (trestbps _|_ chol | fbs, exang, heartdisease, age, restecg, thalach, sex)
# (fbs _|_ exang, sex)
# (fbs _|_ sex | exang)
# (fbs _|_ thalach, chol, restecg | heartdisease)
# (fbs _|_ exang, sex, trestbps | age)
# (fbs _|_ exang | sex)
# (fbs _|_ chol, restecg, thalach | exang, heartdisease)
# (fbs _|_ sex, trestbps | age, exang)
# (fbs _|_ restecg, thalach | chol, heartdisease)
# (fbs _|_ chol, restecg, thalach | heartdisease, trestbps)
# (fbs _|_ exang, sex | age, trestbps)
# (fbs _|_ chol, restecg, thalach | age, heartdisease)
# (fbs _|_ chol, thalach | restecg, heartdisease)
# (fbs _|_ chol, restecg | thalach, heartdisease)
# (fbs _|_ thalach, chol, restecg | sex, heartdisease)
# (fbs _|_ exang, trestbps | age, sex)
# (fbs _|_ restecg, thalach | exang, chol, heartdisease)
# (fbs _|_ chol, restecg, thalach | exang, heartdisease, trestbps)
# (fbs _|_ sex | age, exang, trestbps)
# (fbs _|_ chol, restecg, thalach | age, exang, heartdisease)
# (fbs _|_ chol, thalach | exang, restecg, heartdisease)
# (fbs _|_ chol, restecg | thalach, exang, heartdisease)
# (fbs _|_ chol, restecg, thalach | exang, sex, heartdisease)
# (fbs _|_ trestbps | age, exang, sex)
# (fbs _|_ restecg, thalach | chol, heartdisease, trestbps)
# (fbs _|_ exang, sex | age, chol, trestbps)
# (fbs _|_ restecg, thalach | age, chol, heartdisease)
# (fbs _|_ thalach | chol, restecg, heartdisease)
# (fbs _|_ restecg | thalach, chol, heartdisease)
# (fbs _|_ restecg, thalach | sex, chol, heartdisease)
# (fbs _|_ exang, chol, restecg, thalach, sex | age, heartdisease, trestbps)
# (fbs _|_ chol, thalach | restecg, heartdisease, trestbps)
# (fbs _|_ chol, restecg | thalach, heartdisease, trestbps)
# (fbs _|_ chol, restecg, thalach | sex, heartdisease, trestbps)
# (fbs _|_ exang, sex | age, restecg, trestbps)
# (fbs _|_ exang, sex | age, thalach, trestbps)
# (fbs _|_ exang | age, sex, trestbps)
# (fbs _|_ chol, thalach | age, restecg, heartdisease)
# (fbs _|_ chol, restecg | age, thalach, heartdisease)
# (fbs _|_ chol, restecg, thalach | age, sex, heartdisease)
# (fbs _|_ chol | thalach, restecg, heartdisease)
# (fbs _|_ chol, thalach | sex, restecg, heartdisease)
# (fbs _|_ chol, restecg | thalach, sex, heartdisease)
# (fbs _|_ restecg, thalach | exang, chol, heartdisease, trestbps)
# (fbs _|_ sex | age, exang, chol, trestbps)
# (fbs _|_ restecg, thalach | age, exang, chol, heartdisease)
# (fbs _|_ thalach | exang, chol, restecg, heartdisease)
# (fbs _|_ restecg | thalach, exang, chol, heartdisease)
# (fbs _|_ restecg, thalach | exang, chol, sex, heartdisease)
# (fbs _|_ sex, chol, restecg, thalach | age, exang, heartdisease, trestbps)
# (fbs _|_ chol, thalach | exang, restecg, heartdisease, trestbps)
# (fbs _|_ chol, restecg | thalach, exang, heartdisease, trestbps)
# (fbs _|_ chol, restecg, thalach | exang, sex, heartdisease, trestbps)
# (fbs _|_ sex | age, exang, restecg, trestbps)
# (fbs _|_ sex | age, exang, thalach, trestbps)
# (fbs _|_ chol, thalach | age, exang, restecg, heartdisease)
# (fbs _|_ chol, restecg | age, exang, thalach, heartdisease)
# (fbs _|_ chol, restecg, thalach | age, exang, sex, heartdisease)
# (fbs _|_ chol | thalach, exang, restecg, heartdisease)
# (fbs _|_ chol, thalach | exang, restecg, sex, heartdisease)
# (fbs _|_ chol, restecg | thalach, exang, sex, heartdisease)
# (fbs _|_ exang, restecg, sex, thalach | age, chol, heartdisease, trestbps)
# (fbs _|_ thalach | chol, restecg, heartdisease, trestbps)
# (fbs _|_ restecg | thalach, chol, heartdisease, trestbps)
# (fbs _|_ restecg, thalach | sex, chol, heartdisease, trestbps)
# (fbs _|_ exang, sex | age, chol, restecg, trestbps)
# (fbs _|_ exang, sex | age, chol, thalach, trestbps)
# (fbs _|_ exang | age, sex, chol, trestbps)
# (fbs _|_ thalach | age, chol, restecg, heartdisease)
# (fbs _|_ restecg | age, chol, thalach, heartdisease)
# (fbs _|_ restecg, thalach | age, sex, chol, heartdisease)
# (fbs _|_ thalach | sex, chol, restecg, heartdisease)
# (fbs _|_ restecg | thalach, sex, chol, heartdisease)
# (fbs _|_ exang, chol, sex, thalach | age, restecg, heartdisease, trestbps)
# (fbs _|_ exang, chol, sex, restecg | age, thalach, heartdisease, trestbps)
# (fbs _|_ exang, chol, restecg, thalach | age, sex, heartdisease, trestbps)
# (fbs _|_ chol | thalach, restecg, heartdisease, trestbps)
# (fbs _|_ chol, thalach | sex, restecg, heartdisease, trestbps)
# (fbs _|_ chol, restecg | thalach, sex, heartdisease, trestbps)
# (fbs _|_ exang, sex | age, thalach, restecg, trestbps)
# (fbs _|_ exang | age, sex, restecg, trestbps)
# (fbs _|_ exang | age, sex, thalach, trestbps)
# (fbs _|_ chol | age, thalach, restecg, heartdisease)
# (fbs _|_ chol, thalach | age, sex, restecg, heartdisease)
# (fbs _|_ chol, restecg | age, sex, thalach, heartdisease)
# (fbs _|_ chol | thalach, sex, restecg, heartdisease)
# (fbs _|_ sex, restecg, thalach | exang, chol, trestbps, heartdisease, age)
# (fbs _|_ thalach | exang, chol, trestbps, heartdisease, restecg)
# (fbs _|_ restecg | exang, chol, trestbps, heartdisease, thalach)
# (fbs _|_ restecg, thalach | exang, chol, trestbps, heartdisease, sex)
# (fbs _|_ sex | exang, chol, trestbps, age, restecg)
# (fbs _|_ sex | exang, chol, trestbps, age, thalach)
# (fbs _|_ thalach | exang, chol, heartdisease, age, restecg)
# (fbs _|_ restecg | exang, chol, heartdisease, age, thalach)
# (fbs _|_ restecg, thalach | exang, chol, heartdisease, age, sex)
# (fbs _|_ thalach | exang, chol, heartdisease, restecg, sex)
# (fbs _|_ restecg | exang, chol, heartdisease, thalach, sex)
# (fbs _|_ sex, chol, thalach | exang, trestbps, heartdisease, age, restecg)
# (fbs _|_ sex, chol, restecg | exang, trestbps, heartdisease, age, thalach)
# (fbs _|_ chol, restecg, thalach | exang, trestbps, heartdisease, age, sex)
# (fbs _|_ chol | exang, trestbps, heartdisease, thalach, restecg)
# (fbs _|_ chol, thalach | exang, trestbps, heartdisease, restecg, sex)
# (fbs _|_ chol, restecg | exang, trestbps, heartdisease, thalach, sex)
# (fbs _|_ sex | exang, trestbps, age, thalach, restecg)
# (fbs _|_ chol | exang, heartdisease, age, thalach, restecg)
# (fbs _|_ chol, thalach | exang, heartdisease, age, restecg, sex)
# (fbs _|_ chol, restecg | exang, heartdisease, age, thalach, sex)
# (fbs _|_ chol | exang, heartdisease, thalach, restecg, sex)
# (fbs _|_ exang, sex, thalach | chol, trestbps, heartdisease, age, restecg)
# (fbs _|_ exang, sex, restecg | chol, trestbps, heartdisease, age, thalach)
# (fbs _|_ exang, restecg, thalach | chol, trestbps, heartdisease, age, sex)
# (fbs _|_ thalach | chol, trestbps, heartdisease, restecg, sex)
# (fbs _|_ restecg | chol, trestbps, heartdisease, thalach, sex)
# (fbs _|_ exang, sex | chol, trestbps, age, thalach, restecg)
# (fbs _|_ exang | chol, trestbps, age, restecg, sex)
# (fbs _|_ exang | chol, trestbps, age, thalach, sex)
# (fbs _|_ thalach | chol, heartdisease, age, restecg, sex)
# (fbs _|_ restecg | chol, heartdisease, age, thalach, sex)
# (fbs _|_ exang, chol, sex | trestbps, heartdisease, age, thalach, restecg)
# (fbs _|_ exang, chol, thalach | trestbps, heartdisease, age, restecg, sex)
# (fbs _|_ exang, chol, restecg | trestbps, heartdisease, age, thalach, sex)
# (fbs _|_ chol | trestbps, heartdisease, thalach, restecg, sex)
# (fbs _|_ exang | trestbps, age, thalach, restecg, sex)
# (fbs _|_ chol | heartdisease, age, thalach, restecg, sex)
# (fbs _|_ sex, thalach | exang, chol, trestbps, heartdisease, age, restecg)
# (fbs _|_ sex, restecg | exang, chol, trestbps, heartdisease, age, thalach)
# (fbs _|_ restecg, thalach | exang, chol, trestbps, heartdisease, age, sex)
# (fbs _|_ thalach | exang, chol, trestbps, heartdisease, restecg, sex)
# (fbs _|_ restecg | exang, chol, trestbps, heartdisease, thalach, sex)
# (fbs _|_ sex | exang, chol, trestbps, age, restecg, thalach)
# (fbs _|_ thalach | exang, chol, heartdisease, age, restecg, sex)
# (fbs _|_ restecg | exang, chol, heartdisease, age, thalach, sex)
# (fbs _|_ sex, chol | exang, trestbps, heartdisease, age, restecg, thalach)
# (fbs _|_ chol, thalach | exang, trestbps, heartdisease, age, restecg, sex)
# (fbs _|_ chol, restecg | exang, trestbps, heartdisease, age, thalach, sex)
# (fbs _|_ chol | exang, trestbps, heartdisease, thalach, restecg, sex)
# (fbs _|_ chol | exang, heartdisease, age, thalach, restecg, sex)
# (fbs _|_ exang, sex | chol, trestbps, heartdisease, age, restecg, thalach)
# (fbs _|_ exang, thalach | chol, trestbps, heartdisease, age, restecg, sex)
# (fbs _|_ exang, restecg | chol, trestbps, heartdisease, age, thalach, sex)
# (fbs _|_ exang | chol, trestbps, age, thalach, restecg, sex)
# (fbs _|_ exang, chol | trestbps, heartdisease, age, thalach, restecg, sex)
# (fbs _|_ sex | exang, chol, trestbps, heartdisease, age, restecg, thalach)
# (fbs _|_ thalach | exang, chol, trestbps, heartdisease, age, restecg, sex)
# (fbs _|_ restecg | exang, chol, trestbps, heartdisease, age, thalach, sex)
# (fbs _|_ chol | exang, trestbps, heartdisease, age, restecg, thalach, sex)
# (fbs _|_ exang | chol, trestbps, heartdisease, age, restecg, thalach, sex)
# (sex _|_ fbs, exang, age)
# (sex _|_ age, exang | fbs)
# (sex _|_ fbs, age | exang)
# (sex _|_ thalach, chol, restecg | heartdisease)
# (sex _|_ fbs, exang | age)
# (sex _|_ age | fbs, exang)
# ...
# (thalach _|_ age, exang, sex | fbs, chol, trestbps, heartdisease, restecg)
# (thalach _|_ age, exang, restecg | fbs, chol, trestbps, heartdisease, sex)
# (thalach _|_ exang, sex | fbs, chol, trestbps, age, restecg)
# (thalach _|_ exang | fbs, chol, trestbps, age, sex)
# (thalach _|_ age, exang | fbs, chol, trestbps, restecg, sex)
# (thalach _|_ exang, sex, trestbps | fbs, chol, heartdisease, age, restecg)
# (thalach _|_ exang, restecg, trestbps | fbs, chol, heartdisease, age, sex)
# (thalach _|_ age, exang, trestbps | fbs, chol, heartdisease, restecg, sex)
# (thalach _|_ exang, chol, sex | fbs, trestbps, heartdisease, age, restecg)
# (thalach _|_ exang, chol, restecg | fbs, trestbps, heartdisease, age, sex)
# (thalach _|_ age, exang, chol | fbs, trestbps, heartdisease, restecg, sex)
# (thalach _|_ exang | fbs, trestbps, age, restecg, sex)
# (thalach _|_ exang, chol, trestbps | fbs, heartdisease, age, restecg, sex)
# (thalach _|_ fbs, sex, restecg | exang, chol, trestbps, heartdisease, age)
# (thalach _|_ fbs, age, sex | exang, chol, trestbps, heartdisease, restecg)
# (thalach _|_ fbs, age, restecg | exang, chol, trestbps, heartdisease, sex)
# (thalach _|_ sex | exang, chol, trestbps, age, restecg)
# (thalach _|_ fbs, sex, trestbps | exang, chol, heartdisease, age, restecg)
# (thalach _|_ fbs, restecg, trestbps | exang, chol, heartdisease, age, sex)
# (thalach _|_ fbs, age, trestbps | exang, chol, heartdisease, restecg, sex)
# (thalach _|_ fbs, sex, chol | exang, trestbps, heartdisease, age, restecg)
# (thalach _|_ fbs, chol, restecg | exang, trestbps, heartdisease, age, sex)
# (thalach _|_ fbs, age, chol | exang, trestbps, heartdisease, restecg, sex)
# (thalach _|_ fbs, chol, trestbps | exang, heartdisease, age, restecg, sex)
# (thalach _|_ fbs, exang, sex | chol, trestbps, heartdisease, age, restecg)
# (thalach _|_ fbs, exang, restecg | chol, trestbps, heartdisease, age, sex)
# (thalach _|_ fbs, exang, age | chol, trestbps, heartdisease, restecg, sex)
# (thalach _|_ exang | chol, trestbps, age, restecg, sex)
# (thalach _|_ fbs, exang, trestbps | chol, heartdisease, age, restecg, sex)
# (thalach _|_ fbs, exang, chol | trestbps, heartdisease, age, restecg, sex)
# (thalach _|_ sex, restecg | fbs, exang, chol, trestbps, heartdisease, age)
# (thalach _|_ age, sex | fbs, exang, chol, trestbps, heartdisease, restecg)
# (thalach _|_ age, restecg | fbs, exang, chol, trestbps, heartdisease, sex)
# (thalach _|_ sex | fbs, exang, chol, trestbps, age, restecg)
# (thalach _|_ age | fbs, exang, chol, trestbps, restecg, sex)
# (thalach _|_ sex, trestbps | fbs, exang, chol, heartdisease, age, restecg)
# (thalach _|_ restecg, trestbps | fbs, exang, chol, heartdisease, age, sex)
# (thalach _|_ age, trestbps | fbs, exang, chol, heartdisease, restecg, sex)
# (thalach _|_ sex, chol | fbs, exang, trestbps, heartdisease, age, restecg)
# (thalach _|_ chol, restecg | fbs, exang, trestbps, heartdisease, age, sex)
# (thalach _|_ age, chol | fbs, exang, trestbps, heartdisease, restecg, sex)
# (thalach _|_ chol, trestbps | fbs, exang, heartdisease, age, restecg, sex)
# (thalach _|_ exang, sex | fbs, chol, trestbps, heartdisease, age, restecg)
# (thalach _|_ exang, restecg | fbs, chol, trestbps, heartdisease, age, sex)
# (thalach _|_ age, exang | fbs, chol, trestbps, heartdisease, restecg, sex)
# (thalach _|_ exang | fbs, chol, trestbps, age, restecg, sex)
# (thalach _|_ exang, trestbps | fbs, chol, heartdisease, age, restecg, sex)
# (thalach _|_ exang, chol | fbs, trestbps, heartdisease, age, restecg, sex)
# (thalach _|_ fbs, sex | exang, chol, trestbps, heartdisease, age, restecg)
# (thalach _|_ fbs, restecg | exang, chol, trestbps, heartdisease, age, sex)
# (thalach _|_ fbs, age | exang, chol, trestbps, heartdisease, restecg, sex)
# (thalach _|_ fbs, trestbps | exang, chol, heartdisease, age, restecg, sex)
# (thalach _|_ fbs, chol | exang, trestbps, heartdisease, age, restecg, sex)
# (thalach _|_ fbs, exang | chol, trestbps, heartdisease, age, restecg, sex)
# (thalach _|_ sex | fbs, exang, chol, trestbps, heartdisease, age, restecg)
# (thalach _|_ restecg | fbs, exang, chol, trestbps, heartdisease, age, sex)
# (thalach _|_ age | fbs, exang, chol, trestbps, heartdisease, restecg, sex)
# (thalach _|_ trestbps | fbs, exang, chol, heartdisease, age, restecg, sex)
# (thalach _|_ chol | fbs, exang, trestbps, heartdisease, age, restecg, sex)
# (thalach _|_ exang | fbs, chol, trestbps, heartdisease, age, restecg, sex)
# (thalach _|_ fbs | exang, chol, trestbps, heartdisease, age, restecg, sex)
# (chol _|_ fbs, exang, age, restecg, trestbps, thalach, sex | heartdisease)
# (chol _|_ age, exang, sex | fbs, trestbps)
# (chol _|_ age, exang, restecg, trestbps, thalach, sex | fbs, heartdisease)
# (chol _|_ fbs, age, restecg, trestbps, thalach, sex | exang, heartdisease)
# (chol _|_ fbs, exang, age, restecg, thalach, sex | heartdisease, trestbps)
# (chol _|_ exang, sex | age, trestbps)
# (chol _|_ fbs, exang, restecg, trestbps, thalach, sex | age, heartdisease)
# (chol _|_ fbs, exang, age, thalach, trestbps, sex | restecg, heartdisease)
# (chol _|_ fbs, exang, age, restecg, trestbps, sex | thalach, heartdisease)
# (chol _|_ fbs, exang, age, restecg, trestbps, thalach | sex, heartdisease)
# (chol _|_ age, sex | fbs, exang, trestbps)
# (chol _|_ age, restecg, trestbps, thalach, sex | fbs, exang, heartdisease)
# (chol _|_ age, exang, restecg, thalach, sex | fbs, heartdisease, trestbps)
# (chol _|_ exang, sex | fbs, age, trestbps)
# (chol _|_ age, exang, sex | fbs, restecg, trestbps)
# (chol _|_ age, exang, sex | fbs, thalach, trestbps)
# (chol _|_ age, exang | fbs, sex, trestbps)
# (chol _|_ exang, restecg, trestbps, thalach, sex | fbs, age, heartdisease)
# (chol _|_ age, exang, thalach, trestbps, sex | fbs, restecg, heartdisease)
# (chol _|_ age, exang, restecg, trestbps, sex | fbs, thalach, heartdisease)
# (chol _|_ age, exang, restecg, trestbps, thalach | fbs, sex, heartdisease)
# (chol _|_ fbs, age, restecg, thalach, sex | exang, heartdisease, trestbps)
# (chol _|_ sex | age, exang, trestbps)
# (chol _|_ fbs, restecg, trestbps, thalach, sex | age, exang, heartdisease)
# (chol _|_ fbs, age, thalach, trestbps, sex | exang, restecg, heartdisease)
# (chol _|_ fbs, age, restecg, trestbps, sex | thalach, exang, heartdisease)
# (chol _|_ fbs, age, restecg, trestbps, thalach | exang, sex, heartdisease)
# (chol _|_ fbs, exang, restecg, thalach, sex | age, heartdisease, trestbps)
# (chol _|_ fbs, exang, age, thalach, sex | restecg, heartdisease, trestbps)
# (chol _|_ fbs, exang, age, restecg, sex | thalach, heartdisease, trestbps)
# (chol _|_ fbs, exang, age, restecg, thalach | sex, heartdisease, trestbps)
# (chol _|_ exang, sex | age, restecg, trestbps)
# (chol _|_ exang, sex | age, thalach, trestbps)
# (chol _|_ exang | age, sex, trestbps)
# (chol _|_ fbs, exang, thalach, trestbps, sex | age, restecg, heartdisease)
# (chol _|_ fbs, exang, restecg, trestbps, sex | age, thalach, heartdisease)
# (chol _|_ fbs, exang, restecg, trestbps, thalach | age, sex, heartdisease)
# (chol _|_ fbs, exang, age, trestbps, sex | thalach, restecg, heartdisease)
# (chol _|_ fbs, exang, age, thalach, trestbps | sex, restecg, heartdisease)
# (chol _|_ fbs, exang, age, restecg, trestbps | thalach, sex, heartdisease)
# (chol _|_ age, sex, restecg, thalach | fbs, exang, heartdisease, trestbps)
# (chol _|_ sex | fbs, exang, age, trestbps)
# (chol _|_ age, sex | fbs, exang, restecg, trestbps)
# (chol _|_ age, sex | fbs, exang, thalach, trestbps)
# (chol _|_ age | fbs, exang, sex, trestbps)
# (chol _|_ sex, restecg, thalach, trestbps | fbs, exang, age, heartdisease)
# (chol _|_ age, sex, thalach, trestbps | fbs, exang, restecg, heartdisease)
# (chol _|_ age, sex, restecg, trestbps | fbs, exang, thalach, heartdisease)
# (chol _|_ age, restecg, thalach, trestbps | fbs, exang, sex, heartdisease)
# (chol _|_ exang, restecg, sex, thalach | fbs, age, heartdisease, trestbps)
# (chol _|_ age, exang, sex, thalach | fbs, restecg, heartdisease, trestbps)
# (chol _|_ age, exang, sex, restecg | fbs, thalach, heartdisease, trestbps)
# (chol _|_ age, exang, restecg, thalach | fbs, sex, heartdisease, trestbps)
# (chol _|_ exang, sex | fbs, age, restecg, trestbps)
# (chol _|_ exang, sex | fbs, age, thalach, trestbps)
# (chol _|_ exang | fbs, age, sex, trestbps)
# (chol _|_ age, exang, sex | fbs, thalach, restecg, trestbps)
# (chol _|_ age, exang | fbs, sex, restecg, trestbps)
# (chol _|_ age, exang | fbs, sex, thalach, trestbps)
# (chol _|_ exang, sex, thalach, trestbps | fbs, age, restecg, heartdisease)
# (chol _|_ exang, sex, restecg, trestbps | fbs, age, thalach, heartdisease)
# (chol _|_ exang, restecg, thalach, trestbps | fbs, age, sex, heartdisease)
# (chol _|_ age, exang, sex, trestbps | fbs, thalach, restecg, heartdisease)
# (chol _|_ age, exang, thalach, trestbps | fbs, sex, restecg, heartdisease)
# (chol _|_ age, exang, restecg, trestbps | fbs, sex, thalach, heartdisease)
# (chol _|_ fbs, sex, restecg, thalach | age, exang, heartdisease, trestbps)
# (chol _|_ fbs, age, sex, thalach | exang, restecg, heartdisease, trestbps)
# (chol _|_ fbs, age, sex, restecg | thalach, exang, heartdisease, trestbps)
# (chol _|_ fbs, age, restecg, thalach | exang, sex, heartdisease, trestbps)
# (chol _|_ sex | age, exang, restecg, trestbps)
# (chol _|_ sex | age, exang, thalach, trestbps)
# (chol _|_ fbs, sex, thalach, trestbps | age, exang, restecg, heartdisease)
# (chol _|_ fbs, sex, restecg, trestbps | age, exang, thalach, heartdisease)
# (chol _|_ fbs, restecg, thalach, trestbps | age, exang, sex, heartdisease)
# (chol _|_ fbs, age, sex, trestbps | thalach, exang, restecg, heartdisease)
# (chol _|_ fbs, age, thalach, trestbps | exang, restecg, sex, heartdisease)
# (chol _|_ fbs, age, restecg, trestbps | thalach, exang, sex, heartdisease)
# (chol _|_ fbs, exang, sex, thalach | age, restecg, heartdisease, trestbps)
# (chol _|_ fbs, exang, sex, restecg | age, thalach, heartdisease, trestbps)
# (chol _|_ fbs, exang, restecg, thalach | age, sex, heartdisease, trestbps)
# (chol _|_ fbs, exang, age, sex | thalach, restecg, heartdisease, trestbps)
# (chol _|_ fbs, exang, age, thalach | sex, restecg, heartdisease, trestbps)
# (chol _|_ fbs, exang, age, restecg | thalach, sex, heartdisease, trestbps)
# (chol _|_ exang, sex | age, thalach, restecg, trestbps)
# (chol _|_ exang | age, sex, restecg, trestbps)
# (chol _|_ exang | age, sex, thalach, trestbps)
# (chol _|_ fbs, exang, sex, trestbps | age, thalach, restecg, heartdisease)
# (chol _|_ fbs, exang, thalach, trestbps | age, sex, restecg, heartdisease)
# (chol _|_ fbs, exang, restecg, trestbps | age, sex, thalach, heartdisease)
# (chol _|_ fbs, exang, age, trestbps | thalach, sex, restecg, heartdisease)
# (chol _|_ sex, restecg, thalach | fbs, exang, trestbps, heartdisease, age)
# (chol _|_ age, sex, thalach | fbs, exang, trestbps, heartdisease, restecg)
# (chol _|_ age, sex, restecg | fbs, exang, trestbps, heartdisease, thalach)
# (chol _|_ age, restecg, thalach | fbs, exang, trestbps, heartdisease, sex)
# (chol _|_ sex | fbs, exang, trestbps, age, restecg)
# (chol _|_ sex | fbs, exang, trestbps, age, thalach)
# (chol _|_ age, sex | fbs, exang, trestbps, thalach, restecg)
# (chol _|_ age | fbs, exang, trestbps, restecg, sex)
# (chol _|_ age | fbs, exang, trestbps, thalach, sex)
# (chol _|_ sex, thalach, trestbps | fbs, exang, heartdisease, age, restecg)
# (chol _|_ sex, restecg, trestbps | fbs, exang, heartdisease, age, thalach)
# (chol _|_ restecg, thalach, trestbps | fbs, exang, heartdisease, age, sex)
# (chol _|_ age, sex, trestbps | fbs, exang, heartdisease, thalach, restecg)
# (chol _|_ age, thalach, trestbps | fbs, exang, heartdisease, restecg, sex)
# (chol _|_ age, restecg, trestbps | fbs, exang, heartdisease, thalach, sex)
# (chol _|_ exang, sex, thalach | fbs, trestbps, heartdisease, age, restecg)
# (chol _|_ exang, sex, restecg | fbs, trestbps, heartdisease, age, thalach)
# (chol _|_ exang, restecg, thalach | fbs, trestbps, heartdisease, age, sex)
# (chol _|_ age, exang, sex | fbs, trestbps, heartdisease, thalach, restecg)
# (chol _|_ age, exang, thalach | fbs, trestbps, heartdisease, restecg, sex)
# (chol _|_ age, exang, restecg | fbs, trestbps, heartdisease, thalach, sex)
# (chol _|_ exang, sex | fbs, trestbps, age, thalach, restecg)
# (chol _|_ exang | fbs, trestbps, age, restecg, sex)
# (chol _|_ exang | fbs, trestbps, age, thalach, sex)
# (chol _|_ age, exang | fbs, trestbps, thalach, restecg, sex)
# (chol _|_ exang, sex, trestbps | fbs, heartdisease, age, thalach, restecg)
# (chol _|_ exang, thalach, trestbps | fbs, heartdisease, age, restecg, sex)
# (chol _|_ exang, restecg, trestbps | fbs, heartdisease, age, thalach, sex)
# (chol _|_ age, exang, trestbps | fbs, heartdisease, thalach, restecg, sex)
# (chol _|_ fbs, sex, thalach | exang, trestbps, heartdisease, age, restecg)
# (chol _|_ fbs, sex, restecg | exang, trestbps, heartdisease, age, thalach)
# (chol _|_ fbs, restecg, thalach | exang, trestbps, heartdisease, age, sex)
# (chol _|_ fbs, age, sex | exang, trestbps, heartdisease, thalach, restecg)
# (chol _|_ fbs, age, thalach | exang, trestbps, heartdisease, restecg, sex)
# (chol _|_ fbs, age, restecg | exang, trestbps, heartdisease, thalach, sex)
# (chol _|_ sex | exang, trestbps, age, thalach, restecg)
# (chol _|_ fbs, sex, trestbps | exang, heartdisease, age, thalach, restecg)
# (chol _|_ fbs, thalach, trestbps | exang, heartdisease, age, restecg, sex)
# (chol _|_ fbs, restecg, trestbps | exang, heartdisease, age, thalach, sex)
# (chol _|_ fbs, age, trestbps | exang, heartdisease, thalach, restecg, sex)
# (chol _|_ fbs, exang, sex | trestbps, heartdisease, age, thalach, restecg)
# (chol _|_ fbs, exang, thalach | trestbps, heartdisease, age, restecg, sex)
# (chol _|_ fbs, exang, restecg | trestbps, heartdisease, age, thalach, sex)
# (chol _|_ fbs, exang, age | trestbps, heartdisease, thalach, restecg, sex)
# (chol _|_ exang | trestbps, age, thalach, restecg, sex)
# (chol _|_ fbs, exang, trestbps | heartdisease, age, thalach, restecg, sex)
# (chol _|_ sex, thalach | fbs, exang, trestbps, heartdisease, age, restecg)
# (chol _|_ sex, restecg | fbs, exang, trestbps, heartdisease, age, thalach)
# (chol _|_ restecg, thalach | fbs, exang, trestbps, heartdisease, age, sex)
# (chol _|_ age, sex | fbs, exang, trestbps, heartdisease, restecg, thalach)
# (chol _|_ age, thalach | fbs, exang, trestbps, heartdisease, restecg, sex)
# (chol _|_ age, restecg | fbs, exang, trestbps, heartdisease, thalach, sex)
# (chol _|_ sex | fbs, exang, trestbps, age, restecg, thalach)
# (chol _|_ age | fbs, exang, trestbps, thalach, restecg, sex)
# (chol _|_ sex, trestbps | fbs, exang, heartdisease, age, restecg, thalach)
# (chol _|_ thalach, trestbps | fbs, exang, heartdisease, age, restecg, sex)
# (chol _|_ restecg, trestbps | fbs, exang, heartdisease, age, thalach, sex)
# (chol _|_ age, trestbps | fbs, exang, heartdisease, thalach, restecg, sex)
# (chol _|_ exang, sex | fbs, trestbps, heartdisease, age, restecg, thalach)
# (chol _|_ exang, thalach | fbs, trestbps, heartdisease, age, restecg, sex)
# (chol _|_ exang, restecg | fbs, trestbps, heartdisease, age, thalach, sex)
# (chol _|_ age, exang | fbs, trestbps, heartdisease, thalach, restecg, sex)
# (chol _|_ exang | fbs, trestbps, age, thalach, restecg, sex)
# (chol _|_ exang, trestbps | fbs, heartdisease, age, thalach, restecg, sex)
# (chol _|_ fbs, sex | exang, trestbps, heartdisease, age, restecg, thalach)
# (chol _|_ fbs, thalach | exang, trestbps, heartdisease, age, restecg, sex)
# (chol _|_ fbs, restecg | exang, trestbps, heartdisease, age, thalach, sex)
# (chol _|_ fbs, age | exang, trestbps, heartdisease, thalach, restecg, sex)
# (chol _|_ fbs, trestbps | exang, heartdisease, age, thalach, restecg, sex)
# (chol _|_ fbs, exang | trestbps, heartdisease, age, thalach, restecg, sex)
# (chol _|_ sex | fbs, exang, trestbps, heartdisease, age, restecg, thalach)
# (chol _|_ thalach | fbs, exang, trestbps, heartdisease, age, restecg, sex)
# (chol _|_ restecg | fbs, exang, trestbps, heartdisease, age, thalach, sex)
# (chol _|_ age | fbs, exang, trestbps, heartdisease, restecg, thalach, sex)
# (chol _|_ trestbps | fbs, exang, heartdisease, age, restecg, thalach, sex)
# (chol _|_ exang | fbs, trestbps, heartdisease, age, restecg, thalach, sex)
# (chol _|_ fbs | exang, trestbps, heartdisease, age, restecg, thalach, sex)
